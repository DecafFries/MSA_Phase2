# %% [markdown]
# # MSA 2024 Phase 2 - Part 3

# %% [markdown]
# Welcome to the competition - in Part 3, you are encouraged to utilize neural network based models for classification.
#
# This notebook builds a simple Multi-Layer Perceptron (MLP) model for the CIFAR-10 dataset, with the use of `keras` to define the model structure.

# %% [markdown]
# **Before start working on the competition, please ensure all required libraries are installed and properly set up on your system**:
#
# - `python >= 3.6`,
# - `tensorFlow >= 2.0`,
# - `keras >= 2.3`,
#
# and any neccassary liburaries for data manipulation and processing, e.g., `numpy`, `pandas`, etc.

# %%
import zipfile
import os
import time
from PIL import Image
import numpy as np
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, Dropout
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.regularizers import l2
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import ReduceLROnPlateau

# %% [markdown]
# ### 1. Data loading & preprocessing

# %% [markdown]
# The CIFAR-10 dataset contains 60,000 images(32x32x3) in 10 different classes, with 6,000 images in each class. You can download the dataset directly from the competition webpage.
#
# **To train the model, you are expected to use the training label provided in train.csv**.

# %%
# Function to unzip the dataset
def unzipDataset(data_dir):
    zip_path = data_dir + '.zip'
    extract_path = os.getcwd()

    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

# Paths to the zip files
train_zip_path = 'D:\\MSA_Project\\MSA_Phase2\\datasets\\cifar10\\train'
test_zip_path = 'D:\\MSA_Project\\MSA_Phase2\\datasets\\cifar10\\test'

# Unzip the datasets
unzipDataset(train_zip_path)
unzipDataset(test_zip_path)

# %%
# Paths to the datasets and CSV file
train_dir = 'D:\\MSA_Project\\MSA_Phase2\\datasets\\cifar10\\train'
test_dir = 'D:\\MSA_Project\\MSA_Phase2\\datasets\\cifar10\\test'
train_csv = 'D:\\MSA_Project\\MSA_Phase2\\datasets\\cifar10\\train.csv'

# Load training and testing data
def loadTrain(root_dir, csv_file):
    start_time = time.time()
    ids = []
    images = []
    labels = []
    annotations = np.genfromtxt(csv_file, delimiter=',', names=True)
    for idx in range(len(annotations)):
        img_id = int(annotations['id'][idx])
        img_name = os.path.join(root_dir, f"image_{img_id}.png")
        image = np.array(Image.open(img_name).convert("RGB"))
        label = int(annotations['label'][idx])

        ids.append(img_id)
        images.append(image)
        labels.append(label)
    end_time = time.time()
    print(f"Time taken to load training data: {end_time - start_time:.2f} seconds")
    return np.array(ids), np.array(images), np.array(labels)

def loadTest(root_dir):
    start_time = time.time()
    ids = []
    images = []
    for idx in range(len(os.listdir(root_dir))):
        img_name = os.path.join(root_dir, f"image_{idx}.png")
        image = np.array(Image.open(img_name).convert("RGB"))

        ids.append(idx)
        images.append(image)
    end_time = time.time()
    print(f"Time taken to load testing data: {end_time - start_time:.2f} seconds")
    return np.array(ids), np.array(images)

# %% [markdown]
# ### 2. Build & train the model

# %% [markdown]
# This code demostrates a simple Multi-Layer Perceptron (MLP) model. However, you are encouraged to experiment with more complex deep learning models and techniques to boost your performance.

# %%
# Load training, testing data and the training label provided in train.csv.
id_train, X_train, y_train = loadTrain(train_dir, train_csv)
id_test, X_test = loadTest(test_dir)

# Normalize the data. Reshape the data to fit in to an MLP model.
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# Convert training labels to one-hot encoded vectors.
y_train = to_categorical(y_train, 10)


# Load training and testing data
#id_train, X_train, y_train = loadTrain(train_dir, train_csv)
#id_test, X_test = loadTest(test_dir)

# Normalize the data
#X_train = X_train.astype('float32') / 255.0
#X_test = X_test.astype('float32') / 255.0

# Convert training labels to one-hot encoded vectors
#y_train = to_categorical(y_train, 10)#

# Split the training data into training and validation sets
#X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=101)
# Out:
# Time taken to load training data: 13.51 seconds
# Time taken to load testing data: 1.33 seconds

# %%
# Model initialization
model = Sequential()

# Add Convolutional Layers
model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(32, 32, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(256, activation='relu', kernel_regularizer=l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.6))
model.add(Dense(256, activation='relu', kernel_regularizer=l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.6))
model.add(Dense(10, activation="softmax"))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=512, validation_split=0.2, callbacks=[reduce_lr], verbose=1)
# Out:
# Epoch 1/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.1911 - loss: 8.0773 - val_accuracy: 0.0994 - val_loss: 4.5057 - learning_rate: 0.0010
# Epoch 2/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.3368 - loss: 3.8517 - val_accuracy: 0.1486 - val_loss: 3.4452 - learning_rate: 0.0010
# Epoch 3/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - accuracy: 0.4355 - loss: 2.5741 - val_accuracy: 0.1001 - val_loss: 2.9931 - learning_rate: 0.0010
# Epoch 4/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - accuracy: 0.5004 - loss: 1.9680 - val_accuracy: 0.0998 - val_loss: 2.7659 - learning_rate: 0.0010
# Epoch 5/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - accuracy: 0.5359 - loss: 1.6606 - val_accuracy: 0.1653 - val_loss: 2.6183 - learning_rate: 0.0010
# Epoch 6/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.5694 - loss: 1.4731 - val_accuracy: 0.3000 - val_loss: 2.0870 - learning_rate: 0.0010
# Epoch 7/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 0.5924 - loss: 1.3524 - val_accuracy: 0.3405 - val_loss: 1.9236 - learning_rate: 0.0010
# Epoch 8/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 0.6025 - loss: 1.2834 - val_accuracy: 0.4302 - val_loss: 1.8779 - learning_rate: 0.0010
# Epoch 9/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.6186 - loss: 1.2322 - val_accuracy: 0.4476 - val_loss: 1.8216 - learning_rate: 0.0010
# Epoch 10/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.6340 - loss: 1.1888 - val_accuracy: 0.2187 - val_loss: 2.9440 - learning_rate: 0.0010
# Epoch 11/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.6395 - loss: 1.1740 - val_accuracy: 0.3983 - val_loss: 2.2651 - learning_rate: 0.0010
# Epoch 12/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.6562 - loss: 1.1471 - val_accuracy: 0.3534 - val_loss: 2.2169 - learning_rate: 0.0010
# Epoch 13/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.6767 - loss: 1.0676 - val_accuracy: 0.2421 - val_loss: 3.4842 - learning_rate: 5.0000e-04
# Epoch 14/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.6981 - loss: 1.0021 - val_accuracy: 0.4798 - val_loss: 1.7329 - learning_rate: 5.0000e-04
# Epoch 15/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.7008 - loss: 0.9813 - val_accuracy: 0.4996 - val_loss: 1.6595 - learning_rate: 5.0000e-04
# Epoch 16/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.7127 - loss: 0.9472 - val_accuracy: 0.5398 - val_loss: 1.5527 - learning_rate: 5.0000e-04
# Epoch 17/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - accuracy: 0.7145 - loss: 0.9370 - val_accuracy: 0.4495 - val_loss: 2.0637 - learning_rate: 5.0000e-04
# Epoch 18/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.7206 - loss: 0.9231 - val_accuracy: 0.5300 - val_loss: 1.5770 - learning_rate: 5.0000e-04
# Epoch 19/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 0.7227 - loss: 0.9168 - val_accuracy: 0.5528 - val_loss: 1.5281 - learning_rate: 5.0000e-04
# Epoch 20/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.7303 - loss: 0.8989 - val_accuracy: 0.5536 - val_loss: 1.6073 - learning_rate: 5.0000e-04
# Epoch 21/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 0.7369 - loss: 0.8782 - val_accuracy: 0.5546 - val_loss: 1.4606 - learning_rate: 5.0000e-04
# Epoch 22/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.7381 - loss: 0.8705 - val_accuracy: 0.6279 - val_loss: 1.2038 - learning_rate: 5.0000e-04
# Epoch 23/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - accuracy: 0.7399 - loss: 0.8610 - val_accuracy: 0.4685 - val_loss: 2.0253 - learning_rate: 5.0000e-04
# Epoch 24/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.7517 - loss: 0.8328 - val_accuracy: 0.6167 - val_loss: 1.3189 - learning_rate: 5.0000e-04
# Epoch 25/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - accuracy: 0.7556 - loss: 0.8203 - val_accuracy: 0.5645 - val_loss: 1.6234 - learning_rate: 5.0000e-04
# Epoch 26/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.7672 - loss: 0.7961 - val_accuracy: 0.6716 - val_loss: 1.0848 - learning_rate: 2.5000e-04
# Epoch 27/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.7887 - loss: 0.7283 - val_accuracy: 0.7017 - val_loss: 0.9952 - learning_rate: 2.5000e-04
# Epoch 28/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.7863 - loss: 0.7314 - val_accuracy: 0.6159 - val_loss: 1.3768 - learning_rate: 2.5000e-04
# Epoch 29/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.7939 - loss: 0.7106 - val_accuracy: 0.6581 - val_loss: 1.1887 - learning_rate: 2.5000e-04
# Epoch 30/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - accuracy: 0.8006 - loss: 0.6947 - val_accuracy: 0.6849 - val_loss: 1.0690 - learning_rate: 2.5000e-04
# Epoch 31/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.8124 - loss: 0.6618 - val_accuracy: 0.7075 - val_loss: 0.9853 - learning_rate: 1.2500e-04
# Epoch 32/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.8134 - loss: 0.6494 - val_accuracy: 0.7032 - val_loss: 1.0019 - learning_rate: 1.2500e-04
# Epoch 33/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - accuracy: 0.8183 - loss: 0.6366 - val_accuracy: 0.7130 - val_loss: 0.9614 - learning_rate: 1.2500e-04
# Epoch 34/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.8227 - loss: 0.6221 - val_accuracy: 0.6882 - val_loss: 1.0485 - learning_rate: 1.2500e-04
# Epoch 35/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.8241 - loss: 0.6128 - val_accuracy: 0.6876 - val_loss: 1.0749 - learning_rate: 1.2500e-04
# Epoch 36/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.8272 - loss: 0.6036 - val_accuracy: 0.7025 - val_loss: 1.0156 - learning_rate: 1.2500e-04
# Epoch 37/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - accuracy: 0.8375 - loss: 0.5842 - val_accuracy: 0.7075 - val_loss: 0.9966 - learning_rate: 6.2500e-05
# Epoch 38/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - accuracy: 0.8340 - loss: 0.5790 - val_accuracy: 0.6973 - val_loss: 1.0423 - learning_rate: 6.2500e-05
# Epoch 39/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - accuracy: 0.8414 - loss: 0.5664 - val_accuracy: 0.7023 - val_loss: 1.0264 - learning_rate: 6.2500e-05
# Epoch 40/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - accuracy: 0.8421 - loss: 0.5603 - val_accuracy: 0.7168 - val_loss: 0.9727 - learning_rate: 3.1250e-05
# Epoch 41/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.8453 - loss: 0.5595 - val_accuracy: 0.7146 - val_loss: 0.9698 - learning_rate: 3.1250e-05
# Epoch 42/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - accuracy: 0.8446 - loss: 0.5500 - val_accuracy: 0.7130 - val_loss: 0.9707 - learning_rate: 3.1250e-05
# Epoch 43/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.8511 - loss: 0.5442 - val_accuracy: 0.7119 - val_loss: 0.9661 - learning_rate: 1.5625e-05
# Epoch 44/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.8484 - loss: 0.5482 - val_accuracy: 0.7183 - val_loss: 0.9668 - learning_rate: 1.5625e-05
# Epoch 45/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.8479 - loss: 0.5458 - val_accuracy: 0.7165 - val_loss: 0.9659 - learning_rate: 1.5625e-05
# Epoch 46/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 76ms/step - accuracy: 0.8484 - loss: 0.5460 - val_accuracy: 0.7175 - val_loss: 0.9604 - learning_rate: 7.8125e-06
# Epoch 47/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.8500 - loss: 0.5393 - val_accuracy: 0.7189 - val_loss: 0.9623 - learning_rate: 7.8125e-06
# Epoch 48/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - accuracy: 0.8506 - loss: 0.5369 - val_accuracy: 0.7182 - val_loss: 0.9622 - learning_rate: 7.8125e-06
# Epoch 49/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - accuracy: 0.8546 - loss: 0.5330 - val_accuracy: 0.7184 - val_loss: 0.9643 - learning_rate: 7.8125e-06
# Epoch 50/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - accuracy: 0.8533 - loss: 0.5343 - val_accuracy: 0.7171 - val_loss: 0.9631 - learning_rate: 3.9063e-06

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# Make predictions
predictions = model.predict(X_test)
predicted_labels = np.argmax(predictions, axis=1)

# Prepare the submission file
submission = np.column_stack((id_test, predicted_labels))

# Save the submission file to the desired path
submission_file_path = 'D:\\MSA_Project\\MSA_Phase2\\outputs\\submission.csv'
np.savetxt(submission_file_path, submission, delimiter=',', header='id,label', comments='', fmt='%d')
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
